# %%
import pandas as pd

# %%
df = pd.read_csv('Data.csv')

print(df.to_string())
# Out:
#     gender  NationalITy PlaceofBirth       StageID GradeID SectionID      Topic Semester Relation  raisedhands  VisITedResources  AnnouncementsView  Discussion ParentAnsweringSurvey ParentschoolSatisfaction StudentAbsenceDays Class
# 0        M           KW       KuwaIT    lowerlevel    G-04         A         IT        F   Father         15.0              16.0                  2          20                   Yes                     Good            Under-7     M
# 1        M           KW       KuwaIT    lowerlevel    G-04         A         IT        F   Father         20.0              20.0                  3          25                   Yes                     Good            Under-7     M
# 2        M           KW       KuwaIT    lowerlevel    G-04         A         IT        F   Father         10.0               7.0                  0          30                    No                      Bad            Above-7     L
# ...

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father         15.0                16                  2
# 1        F   Father         20.0                20                  3
# 2        F   Father         10.0                 7                  0
# 3        F   Father         30.0                25                  5
# 4        F   Father         40.0                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.tail()
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 475  Chemistry        S   Father          5.0                 4
# 476    Geology        F   Father         50.0                77
# 477    Geology        S   Father         55.0                74
# 478    History        F   Father         30.0                17
# 479    History        S   Father         35.0                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 475                  5           8                    No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               479 non-null    float64
#  10  VisITedResources          478 non-null    float64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
# new_df = df.dropna()
# new_df.info()

# %%
# df.dropna(inplace = True)
# df

# %%
df["raisedhands"].fillna(df["raisedhands"].mode()[0], inplace = True)
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...

# %%
df["raisedhands"].mean()
# At last one value
# except only on value
# Out:
# 46.9

# %%
df["raisedhands"].mode()
# At least on value
# except more than on value
# Out:
# 0    70.0
# dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=480, step=1)

# %%
#Check for variables that is outlayer
for index in df.index:
    if df.loc[index,"VisITedResources"] > 100:
        print(df.loc[index])
# Out:
# gender                               F
# NationalITy                       Iraq
# PlaceofBirth                      Iraq
# StageID                     lowerlevel
# GradeID                           G-02
# SectionID                            B
# Topic                           Arabic
# Semester                             F
# Relation                           Mum
# raisedhands                         89
# VisITedResources                   102
# AnnouncementsView                   40
# Discussion                          28
# ParentAnsweringSurvey              Yes
# ParentschoolSatisfaction          Good
# StudentAbsenceDays             Under-7
# Class                                H
# Name: 384, dtype: object	gender                                 M
# NationalITy                    Palestine
# PlaceofBirth                      Jordan
# StageID                     MiddleSchool
# GradeID                             G-08
# SectionID                              A
# ...

# %%
for i in df.index:
    # print(df.loc[i])
    # print(df.loc[i, "VisITedResources"])
    if df.loc[i , "VisITedResources"]>100:
        df.loc[i , "VisITedResources"] = df["VisITedResources"].mode()[0]
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# Length: 480, dtype: bool

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0                16
# ...
